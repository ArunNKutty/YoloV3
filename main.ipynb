# %% [markdown]
# # Assignment 11 - Arun Kutty

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# %cd /content/drive/MyDrive/S12/YoloV3
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/S12/YoloV3

# %%
# %ls
# Out:
#  annotation_tool/   main.ipynb     README.md      runs/              train.py            weights/
#  cfg/               models.py      results.json   test.py           'ubdivisions=1'
#  data/              output/        results.png    ting               utils/
#  detect.py          __pycache__/   results.txt    train_batch0.png   vim.exe.stackdump

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.25.2

# %%
# !pip install numpy --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 39.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
# ...

# %%
# !python train.py --data data/data/custom.data --weights weights/yolov3-spp-ultralytics.pt --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 25 --nosave
# Out:
# Namespace(epochs=25, batch_size=10, accumulate=4, cfg='cfg/yolov3-custom.cfg', data='data/data/custom.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=True, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/yolov3-spp-ultralytics.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# 2024-04-22 16:37:33.978812: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-22 16:37:33.978862: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/S12/YoloV3

# %%
# !python detect.py --source data/data/images --names data/data/custom.names --weights weights/last.pt
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/data/custom.names', weights='weights/last.pt', source='data/data/images', output='output', img_size=512, conf_thres=0.3, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# Model Summary: 225 layers, 4.4214e+07 parameters, 4.4214e+07 gradients
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/102 data/data/images/352.jpg: 384x512 Done. (0.057s)
# image 2/102 data/data/images/353 copy.jpg: 384x512 Done. (0.021s)
# image 3/102 data/data/images/353.jpg: 384x512 Done. (0.021s)
# ...
